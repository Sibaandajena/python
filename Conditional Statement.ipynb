# %% [markdown]
# # if-elif-else Statemet

# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if True:
    print('ds')
# Out:
# ds

# %%
if False:
    print('Data Science')
print('Data Science')
# Out:
# Data Science

# %%
if True:
    print('Data Science')
print('Data Analysis')
# Out:
# Data Science
# Data Analysis

# %%
if False:
    print('Data Science')
else:
    print('Data Analysis')
# Out:
# Data Analysis

# %%
# EVEN ODD CHECK

num=int(input('enter your number')) #--> input fumction

if(num % 2 ==0):
    print('even')
else:
    print('odd')
# Out:
# odd

# %%
# check a person is eligible to drive

age=int(input('entwer your age:'))
if(age <= 18):
    print('your age is under 18 so you cannot drive')

elif(age>=60):
    print('you cannot drive')

else:
    print('you can drive')
# Out:
# your age is under 18 so you cannot drive

# %%
# check a person is elegible to vote

age=17
if(age >= 18):
    print('your can vote')

else:
    print('you cannot vote')
# Out:
# you cannot vote

# %%
# fint the gretest number between two number

num1=8
num2=9

if(num1>num2):
    print('num1 is gretest')
else:
    print('num2 is gretest')
# Out:
# num2 is gretest

# %%
# A nimber is divisible by 5
num=4
if(num % 5 == 0):
    print('divisible by 5')
else:
    print('not divisible')
# Out:
# not divisible

# %%
# find the largest of number 3 number 

num1=9
num2=7
num3=8

if(num1>num2 and num1>num3):
    print('num1 is largest number')
elif(num2>num1 and num2>num3):
    print('num2 is largest number')
else:
    print('num3 is largest number')
# Out:
# num1 is largest number

# %%
# LEAP Year
year=2025

if(year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print('leap year')
else:
    print('not leap year')
# Out:
# not leap year

# %%
# a number is multiple of both 3 and 7
num=21

if(num % 7 == 0 and year % 3==0):
    print('The number is a multiple of both 3 and 7')
else:
    print('The number is not a multiple of both 3 and 7')
# Out:
# The number is a multiple of both 3 and 7

# %%
# character is a vowel or consonant.
char='a'
if(char == 'a','e','i','o','u','A','E','I','O','U'):
    print('it is a vowel')
else:
    print('it is a consonant')
# Out:
# it is a vowel

# %%
#checks if a number is between 10 and 50.
num=58

if(num>10 and num<50):
    print('The number is between 10 and 50')
else:
    print('The number is not between 10 and 50')
# Out:
# The number is not between 10 and 50

# %%
# Write a program to calculate grade based on marks:

mark= 89

if(mark >= 90 and mark<= 100):
    print('your greade is A')

elif(mark >= 75 and mark<= 89):
    print('your greade is B')

elif(mark >= 50 and mark<= 74):
    print('your greade is C')

else:
    print('you are fail')
# Out:
# your greade is B

# %%
#Write a program to check whether a number is positive, negative, or zero

number=-1

if(number > 0):
   print('positive number')
elif(number < 0):
    print('negative number')
else:
    print('zero')
# Out:
# negative number

# %%
# Write a program to find discount:

#If price > 5000 → 20% discount
#If price > 2000 → 10% discount
#Otherwise → No discount

price=6000
discout=0

if(price > 5000):
    discount = price*0.20
elif(discount < 2000):
    discount = price*0.10
else:
    discount = 0

final_price = price-discount

print('Discount:' , discount)
print('Final price:' , final_price)
# Out:
# Discount: 1200.0
# Final price: 4800.0

# %%
# Write a program to check if a number is a 3-digit number.

number=888

if(number<100 and number >= 100 and number <1000):
    print(number ,'this number is 3-digits')
else:
    print(number, 'this number is not 3-digits')
# Out:
# 888 this number is not 3-digits

# %%
num = int(input("Enter a number: ")) 
print("Square:", num ** 2)
# Out:
# Square: 64

# %%
num = int(input("Enter a number: ")) 
print("que:", num ** 3)
# Out:
# que: 343

# %%
#Write a Python program that takes two numbers as input and prints their product.

num1=int(input('enter your first number'))
num2=int(input('enter yout second number'))

print('product', num1 * num2)
# Out:
# product 45

# %%
# Crating Calculator:

num1=int(input('enter your first number'))
num2=int(input('enter yout second number'))

operater=(input('+ , - , / , * , % '))

if(operater== '+'):
    print(num1+num2)

elif(operater== '-'):
    print(num1-num2)

elif(operater== '/'):
    print(num1/num2)

elif(operater== '*'):
    print(num1*num2)


elif(operater== '%'):
    print(num1%num2)
else:
    print('i dont know')
# Out:
# 16

# %%
p = [1,2,3,4,45,5,666,6,5,4,2,3,3,43,4,44,4,4]
q = set(p)
q
# Out:
# {1, 2, 3, 4, 5, 6, 43, 44, 45, 666}

# %%
age=int(input('enter your age:'))
drive=input('are you know driving: yes/no')
licance=input('are you have licance: yes/no')

if(age>=18):
    print('now you can drive')
    if(drive == 'yes'):
        print('apply for licance')
        if(licance== 'yes'):
            print('you are eligble for driving')
else:
    print('your age is:',age ,'so you are not eligble for driving')
# Out:
# your age is: 5 so you are not eligble for driving

# %%
# chek you are eligible for driving 

age=int(input('enter your age:'))
drive=input('are you know driving: yes/no:')
licance=input('are you have licance: yes/no":')

if(age>=18):
    print('you are eligible for drive')
    
    if(drive == 'yes'):
        print('you know driving so now you can drive')
    else:
        print('you dont know driving so you first learn drive')
        
        if(licance== 'yes'):
            print('you have licance so you can drive')
        else:
            print('you have no licance so first you can apply licance')
            
else:
    print('your age is:',age ,'so you are not eligble for driving')
# Out:
# you are eligible for drive
# you know driving so now you can drive
